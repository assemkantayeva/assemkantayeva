# %%
! pip install gTTS

# %%
from gtts import gTTS
import os

# %%
textToRead = "Hello, how are you? "

# %%
language = "en"

# %%
mySoundFile = gTTS(text = textToRead, slow = False)
mySoundFile.save("Hello.mp3")
